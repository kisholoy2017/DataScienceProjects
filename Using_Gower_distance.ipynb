# %%
# !pip install gower

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dbbffae8-a7aa-45c2-b094-eee0236e4903" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbbffae8-a7aa-45c2-b094-eee0236e4903">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

df = pd.read_csv(io.BytesIO(uploaded['data (1).csv']))
df.head()
# Out:
#    Product ID   Brand Product Category Price Band Seasonality Element  \
# 0           1  BrandD           serums       High                Fall
# 1           2  BrandE           serums        Low              Spring
# 2           3  BrandC           serums     Medium              Spring
# 3           4  BrandE       gift packs        Low              Winter
# 4           5  BrandE        body oils       High              Spring
#
#   Offer/Promotion
# 0              No
# 1             Yes
# 2              No
# 3             Yes
# 4              No

# %%
import gower

distance_matrix = gower.gower_matrix(df)

distance_matrix
# Out:
# array([[0.        , 0.670068  , 0.50680274, ..., 0.65986395, 0.6632653 ,
#         0.5       ],
#        [0.670068  , 0.        , 0.50340134, ..., 0.6564626 , 0.82653064,
#         0.99659866],
#        [0.50680274, 0.50340134, 0.        , ..., 0.6530612 , 0.9897959 ,
#         0.65986395],
#        ...,
#        [0.65986395, 0.6564626 , 0.6530612 , ..., 0.        , 0.50340134,
#         0.67346936],
#        [0.6632653 , 0.82653064, 0.9897959 , ..., 0.50340134, 0.        ,
#         0.670068  ],
#        [0.5       , 0.99659866, 0.65986395, ..., 0.67346936, 0.670068  ,
#         0.        ]], dtype=float32)

# %%
gower_df = pd.DataFrame(distance_matrix, index=df["Product ID"], columns=df["Product ID"])

# %%
gower_df
# Out:
# Product ID        1         2         3         4         5         6   \
# Product ID
# 1           0.000000  0.670068  0.506803  0.843537  0.513605  0.683673
# 2           0.670068  0.000000  0.503401  0.340136  0.510204  0.680272
# 3           0.506803  0.503401  0.000000  0.836735  0.506803  0.843537
# 4           0.843537  0.340136  0.836735  0.000000  0.670068  0.506803
# 5           0.513605  0.510204  0.506803  0.670068  0.000000  0.670068
# 6           0.683673  0.680272  0.843537  0.506803  0.670068  0.000000
# 7           0.520408  0.683673  0.180272  0.676871  0.673469  0.670068
# 8           0.690476  0.520408  0.350340  0.680272  0.510204  0.840136
# 9           0.193878  0.690476  0.353741  0.850340  0.513605  0.676871
# 10          0.530612  0.693878  0.523810  0.687075  0.517007  0.846939
# 11          0.367347  0.697279  0.860544  0.690476  0.687075  0.517007
# 12          0.204082  0.700680  0.363946  0.860544  0.523810  0.687075
# ...

# %%
gower_df.to_csv('data.csv', index=False)

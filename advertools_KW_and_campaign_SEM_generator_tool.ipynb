# %%
# !pip list -v
# Out:
# Package                       Version                Location                               Installer
# ----------------------------- ---------------------- -------------------------------------- ---------
# absl-py                       1.3.0                  /usr/local/lib/python3.8/dist-packages pip
# aeppl                         0.0.33                 /usr/local/lib/python3.8/dist-packages pip
# aesara                        2.7.9                  /usr/local/lib/python3.8/dist-packages pip
# aiohttp                       3.8.3                  /usr/local/lib/python3.8/dist-packages pip
# aiosignal                     1.3.1                  /usr/local/lib/python3.8/dist-packages pip
# alabaster                     0.7.12                 /usr/local/lib/python3.8/dist-packages pip
# albumentations                1.2.1                  /usr/local/lib/python3.8/dist-packages pip
# altair                        4.2.0                  /usr/local/lib/python3.8/dist-packages pip
# ...

# %%
# !pip install advertools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.1/310.1 KB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.5/271.5 KB 25.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 81.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 KB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 KB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 KB 23.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 94.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 KB 8.6 MB/s eta 0:00:00
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.6-py3-none-any.whl size=11959 sha256=c4d599d3cb674dd6a3fb97b9664a44bee4db918fe68a22201748cb66286e0f54
# ...

# %%
import advertools as adv

products = ['enginering', 'marketing']
words = ['jobs', 'hybrid', 'salary', 'full-time']

kw_df = adv.kw_generate(products, words)
kw_df
# Out:
#          Campaign    Ad Group                        Keyword Criterion Type  \
# 0    SEM_Campaign  Enginering                enginering jobs          Exact
# 1    SEM_Campaign  Enginering                enginering jobs         Phrase
# 2    SEM_Campaign  Enginering              +enginering +jobs          Broad
# 3    SEM_Campaign  Enginering              enginering hybrid          Exact
# 4    SEM_Campaign  Enginering              enginering hybrid         Phrase
# ..            ...         ...                            ...            ...
# 259  SEM_Campaign   Marketing     full-time hybrid marketing         Phrase
# 260  SEM_Campaign   Marketing  +full-time +hybrid +marketing          Broad
# 261  SEM_Campaign   Marketing     full-time salary marketing          Exact
# 262  SEM_Campaign   Marketing     full-time salary marketing         Phrase
# 263  SEM_Campaign   Marketing  +full-time +salary +marketing          Broad
#
#                Labels
# 0                Jobs
# ...

# %%
kw_df.groupby(["Ad Group"]).count().sort_values(["Keyword"])
# Out:
#             Campaign  Keyword  Criterion Type  Labels
# Ad Group
# Enginering       132      132             132     132
# Marketing        132      132             132     132

# %%
kw_new = kw_df.groupby('Ad Group')

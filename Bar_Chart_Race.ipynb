# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-31820975-6906-4e64-aafd-a59b7f0a68b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31820975-6906-4e64-aafd-a59b7f0a68b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['State.csv']))
df.head()
# Out:
#        Date  California  Texas  Florida  North Carolina  Alabama  Michigan  \
# 0  20230822          35     27       33              19       56        20
# 1  20230829          43     25       27              19       47        34
# 2  20230816          43     34       28               8       57        39
# 3  20230821          37     31       25              18       48        24
# 4  20230811          48     23       29               6       61        24
#
#    Oregon  Washington
# 0      12          55
# 1      32          52
# 2      43          50
# 3      42          43
# 4      40          36

# %%
df.set_index("Date", inplace = True)

# %%
#from 3rd to 30th Aug
df.head()
# Out:
#           California  Texas  Florida  North Carolina  Alabama  Michigan  \
# Date
# 20230822          35     27       33              19       56        20
# 20230829          43     25       27              19       47        34
# 20230816          43     34       28               8       57        39
# 20230821          37     31       25              18       48        24
# 20230811          48     23       29               6       61        24
#
#           Oregon  Washington
# Date
# 20230822      12          55
# 20230829      32          52
# 20230816      43          50
# 20230821      42          43
# 20230811      40          36

# %%
# !pip install bar_chart_race
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 3.4 MB/s eta 0:00:00
# ...

# %%
import bar_chart_race as bcr

# %%
bcr.bar_chart_race(df=df, title = "Sessions by Location")
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="952" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
df = df.sort_values(by = "Date")

# %%
df.head()
# Out:
#           California  Texas  Florida  North Carolina  Alabama  Michigan  \
# Date
# 20230803          32     17       26              16       14        40
# 20230804          39     17       26               9       47        24
# 20230805          33     19       22              15       38        34
# 20230806          48     21       21               9       20        32
# 20230807          25     32       16               6       12        22
#
#           Oregon  Washington
# Date
# 20230803      34          16
# 20230804      33          49
# 20230805      18          56
# 20230806      52          51
# 20230807      55          30

# %%
bcr.bar_chart_race(df=df, title = "Sessions by Location", period_length=2000)
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="952" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
output_filename = 'BCR2.mp4'

# %%
bcr.bar_chart_race(df=df, title = "Sessions by Location", period_length=2000, filename=output_filename)
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))

# %%
import matplotlib.pyplot as plt
from PIL import Image
